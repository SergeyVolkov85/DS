# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера</b>
#
#
#
# Привет! Меня зовут Светлана Носова, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
#
#
# Сразу хочу обратить внимание на цветовую разметку.
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным  обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме перечисленных.**
# Также я попрошу тебя **не менять, не передвигать и не удалять мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# **По проекту:** работа очень объемная и непростая, ты молодец. Структура хорошая, много анализа, графиков и выводов. Хорошо проработаны пропущенные значения и выбросы. У меня остались некоторые вопросы, я все написала в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
#
# <hr style="border-top: 3px solid purple; "></hr>
# Комментарии можешь оставлять с помощью такого кода в Markdown ячейке:
#
#
#     <div class="alert alert-info">
#     <h2> Комментарий студента</h2>
#
#     Тут текст.
#     </div>
#
#
#     <font color='red'> Этот код позволяет менять цвет текста. </font>
#
#
# <font color='red'> Выглядит это так. </font>
#
#
#
# Если не хочешь, чтобы твои комментарии отображались в содержании как заголовки, замени **h2** на **b** или добавь `<a class="tocSkip">` после фразы *Комментарий студента*.
# </div>

# %% [markdown]
#  <div class="alert alert-info">
# <b> Привет, меня зовут Волков Сергей! Полностью поддреживаю общение на "ты". Спасибо за комментарии, отдельное спасибо за код с высотой потолков, я чувствовал, что можно сделать проще, но не смог додуматься...) Постарался учесть все твои комментарии</b>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Приятно познакомиться :) Вопросов у меня больше нет, поэтому проект могу принять :) Желаю успехов в дальнейшем обучении :)
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Поменял-масштаб,-но-сильно-изиенился-график" data-toc-modified-id="Поменял-масштаб,-но-сильно-изиенился-график-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Поменял масштаб, но сильно изиенился график</a></span></li><li><span><a href="#-Комментарий-ревьюера-2" data-toc-modified-id="-Комментарий-ревьюера-2-4"><span class="toc-item-num">4&nbsp;&nbsp;</span> Комментарий ревьюера 2</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Да,-спасибо,-ограничил,-квартиры-квартиры-более-500-кв.-м.-выглядят-не-провдаподобно-и-цена-763-млн-тоже" data-toc-modified-id="Да,-спасибо,-ограничил,-квартиры-квартиры-более-500-кв.-м.-выглядят-не-провдаподобно-и-цена-763-млн-тоже-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Да, спасибо, ограничил, квартиры квартиры более 500 кв. м. выглядят не провдаподобно и цена 763 млн тоже</a></span></li><li><span><a href="#-Спасибо,-учёл-комментарий,-на-счет-диаметра-18-км-согласен,-но-я-не-нашел-в-свободных-источниках,-какой-радиус-в-Питере-считается-центром,-я-руководствовался-такой-логикой,-сам-долгое-время-проживал-в-Краснодаре,-центр-краснодара-это-диаметр-примерно-8-9-метров,-ну-и-масштабировал-на-Питер)),-плюс-у-Краснодара-например-условно-два-центра,-&quot;старый&quot;-и-&quot;новый&quot;.-Но-видимо,-ты-или-живешь/жила-в-Санкт-Петербргу-или-много-работала-с-недвижимостью,-поверю-профи...)--Максимум,-что-я-нашел-это-районы-относящеся-к-центру,-а-именно-Адмиралтейского,-Невского,-Василеостровской-также-относят-Петроградский,-попробовал-проверить-по-гугл-картам,-примерно-вышло-7,2-км.-![image.png](attachment:image.png)--------
# --©-https://peterburg.center/story/gde-centr-sankt-peterburga.html-" data-toc-modified-id="-Спасибо,-учёл-комментарий,-на-счет-диаметра-18-км-согласен,-но-я-не-нашел-в-свободных-источниках,-какой-радиус-в-Питере-считается-центром,-я-руководствовался-такой-логикой,-сам-долгое-время-проживал-в-Краснодаре,-центр-краснодара-это-диаметр-примерно-8-9-метров,-ну-и-масштабировал-на-Питер)),-плюс-у-Краснодара-например-условно-два-центра,-&quot;старый&quot;-и-&quot;новый&quot;.-Но-видимо,-ты-или-живешь/жила-в-Санкт-Петербргу-или-много-работала-с-недвижимостью,-поверю-профи...)--Максимум,-что-я-нашел-это-районы-относящеся-к-центру,-а-именно-Адмиралтейского,-Невского,-Василеостровской-также-относят-Петроградский,-попробовал-проверить-по-гугл-картам,-примерно-вышло-7,2-км.-![image.png](attachment:image.png)--------
# --©-https://peterburg.center/story/gde-centr-sankt-peterburga.html--8"><span class="toc-item-num">8&nbsp;&nbsp;</span> Спасибо, учёл комментарий, на счет диаметра 18 км согласен, но я не нашел в свободных источниках, какой радиус в Питере считается центром, я руководствовался такой логикой, сам долгое время проживал в Краснодаре, центр краснодара это диаметр примерно 8-9 метров, ну и масштабировал на Питер)), плюс у Краснодара например условно два центра, "старый" и "новый". Но видимо, ты или живешь/жила в Санкт-Петербргу или много работала с недвижимостью, поверю профи...)  Максимум, что я нашел это районы относящеся к центру, а именно Адмиралтейского, Невского, Василеостровской также относят Петроградский, попробовал проверить по гугл картам, примерно вышло 7,2 км. ![image.png](attachment:image.png)
#   © https://peterburg.center/story/gde-centr-sankt-peterburga.html </a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Правильно делаешь, что добавляешь краткое описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# **Сделаем импорт библиотек**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Считаем датасет**

# %%
#data = pd.read_csv('/datasets/real_estate_data.csv')
#data  данные склеились, вставим как разделитель знак табуляции '\t'
data = pd.read_csv('/datasets/real_estate_data.csv',sep = '\t', decimal = '.')
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# *для наглядности сделаем оставим себе подсказку в виде описания данных*

# %% [raw]
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# balcony — число балконов
# ceiling_height — высота потолков (м)
# cityCenters_nearest — расстояние до центра города (м)
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# first_day_exposition — дата публикации
# floor — этаж
# floors_total — всего этажей в доме
# is_apartment — апартаменты (булев тип)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# last_price — цена на момент снятия с публикации
# living_area — жилая площадь в квадратных метрах(м²)
# locality_name — название населённого пункта
# open_plan — свободная планировка (булев тип)
# parks_around3000 — число парков в радиусе 3 км
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_around3000 — число водоёмов в радиусе 3 км
# ponds_nearest — расстояние до ближайшего водоёма (м)
# rooms — число комнат
# studio — квартира-студия (булев тип)
# total_area — площадь квартиры в квадратных метрах (м²)
# total_images — число фотографий квартиры в объявлении

# %% [markdown]
# **Постмотрим основную информацию о датасете**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблице 22 столбца и 23699 строк. Наимнования столбцов указывают на информацию о квартире и ее местоположении. В таблице данные разных типов, имеюется большое кол-во пропусков. Пропуски в высоте потолков, размерах жилой площади и кухни, возможно они стндартных размеров. Исходя из этого, по среднему значению или медиане можно будет заполнить пропуски. Информацию о наличие балкона, водоемов, парка, возможно, сочли не нужной или они остсутствуют как таковые, т.к. в задинии говорится, что они получены автоматически. Также есть  пропуски в количестве дней, в течение которых висело объявление до продажи кварир

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Хорошая вводная часть. </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Посмотрим в каих столбцах и какое кол-во пропусков

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# is_apartment            20924
# parks_nearest           15620
# ponds_nearest           14589
# balcony                 11519
# ceiling_height           9195
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# ponds_around3000         5518
# days_exposition          3181
# kitchen_area             2278
# living_area              1903
# floors_total               86
# locality_name              49
# first_day_exposition        0
# last_price                  0
# total_area                  0
# studio                      0
# rooms                       0
# floor                       0
# open_plan                   0
# total_images                0
# dtype: int64

# %% [markdown]
# **Для наглядности покажим на графике**

# %%
data.isnull().sum().sort_values(ascending = False).plot(kind='bar',figsize=(15,5))

# %% [markdown]
# ***Пропусков очень много, начнё поэтапно их заполнять... Будем двигаться от простого к сложному.***

# %% [markdown]
# Заполним пропуски в столбце балкон, пропуск стоит скорей всего там, где балкон отсутствуетб, соответственно заменим пропуск на 0.

# %%
data.loc[data['balcony'].isnull(), 'balcony'] = 0
print(data['balcony'].isnull().sum())
# Out:
# 0

# %% [markdown]
# Убарли пропуски с толбце 'balcony'

# %% [markdown]
# **Изучим высоту потолков**

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.boxplot('ceiling_height')

plt.ylim(-1, 100,)
# Out:
# (-1, 100)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# График можно масштабировать с помощью параметра **ylim**.</div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Поменял масштаб, но сильно изиенился график</h2>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2</h2>
#
# Так он изначально был от -1 до 100 :)</div>

# %%
# КОД РЕВЬЮЕРА

data.boxplot('ceiling_height')

plt.ylim(-1, 5)
# Out:
# (-1, 5)

# %% [markdown]
#     Нижний ус упирается в 1 м, верхний в 100 м, min и max значения это выбросы, скоерей всего были заполнены ошибочно, средняя высота 2,77 м похоже на правду, высота потолков в квартирах варируется от 2,4 до 3 м. если обратися к СНиП, в "хрущевках" высота потолков 2,4 (где высота жилых комнат2.5 м коридоры 2,2 м), в современных квартирах по СНиП высота потолков 2,6 м, в элитных домах 3 и более метров, но чаще не более 4 м.
#     Думаю логично будет заполнить медианой в зависимоти от населенного пункта. Но перед этим посмотрим коррелируетс ли как-то высота потолков от остальных параметров в датасете

# %%
data.corr()
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.104473    0.115352  0.099288
# last_price               0.104473    1.000000    0.653675  0.363343
# total_area               0.115352    0.653675    1.000000  0.758344
# rooms                    0.099288    0.363343    0.758344  1.000000
# ceiling_height          -0.001987    0.085430    0.095490  0.054457
# floors_total             0.010427   -0.006984   -0.075774 -0.228215
# living_area              0.104780    0.566492    0.939537  0.845977
# floor                    0.031340    0.026576   -0.024754 -0.150862
# studio                  -0.029303   -0.025362   -0.072653 -0.147286
# open_plan               -0.024407   -0.008802   -0.034885 -0.087500
# kitchen_area             0.104756    0.519869    0.609121  0.269945
# balcony                  0.048903    0.008559    0.009941 -0.015519
# airports_nearest        -0.002298   -0.026239   -0.030753 -0.061199
# ...

# %% [markdown]
# **Высота потолков не зависит напрямую от размера квариры, количества комнат и т д. В нашем случае она зависит  она зависит от типа жилья, займемся заменой пропусков по медиане.

# %% [markdown]
# *Создадим дополнительный столбец*

# %%
data['ceiling_height_median']=0
def ceiling_heigh(row):
    row['ceiling_height_median'] = data.loc[data['locality_name'] == row['locality_name'], 'ceiling_height'].median()
    return row['ceiling_height_median']
data['ceiling_height_median'] = data.apply(ceiling_heigh, axis = 1)
data.loc[data['ceiling_height'].isnull() == True, 'ceiling_height'] = data['ceiling_height_median']
data
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Верно. Потолки это довольно стандартизированная величина, поэтому можно безболезненно заменить их медианой. Для СПб можно добавить группировку по расстоянию до центра.
# </div>

# %%
data['ceiling_height'].isnull().sum()
# Out:
# 156

# %%
#data_ceiling_height = data.pivot_table(index='locality_name', values='ceiling_height')

#data_ceiling_height.query('ceiling_height == "NaN"') что-то я делаю не так, код не работает

# %% [markdown]
# Чать пропусков осталась, а имеено там где отстутсвует название населенного пункта, и  он в единственном числе. Это 156 пропусков из 23699, что составляет 0,65%, удалим их.

# %%
data.drop(data[data['ceiling_height'].isnull() == True].index, inplace=True)
data['ceiling_height'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Изучим пропуски в столбце is_apartment - апартаменты. Заменим пропуски на False,т.к. эти данные не вводились, следовательно скорее всего это не апартаменты.**

# %%
#data['is_apartment'] == 'NaN'.index
data.loc[data['is_apartment'].isna(),'is_apartment'] = False
data['is_apartment'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Изучим пропуски в столбце living_area - жилая площадь**

# %%
#data['living_area'].plot()corr(data['rooms'])
data['living_area'].corr(data['rooms'])
# Out:
# 0.8460848580752747

# %% [markdown]
#     Видим высукую корреляцию жилой площади квартиры от кол-во комнат.Посмторим какую часть общей площади квартиры занимает жилая площадь для однокомнатной, двухкомнатной и т д квартир. Посмотрим, сколько квартирах с разным кол-вом комнат в датасете

# %%
data['rooms'].value_counts()
# Out:
# 1     8002
# 2     7871
# 3     5779
# 4     1175
# 5      326
# 0      195
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# **Больше всего квартир с кол-во комнат от 1 до 9 шт.**

# %%
print ((data.loc[(data['rooms'] == 0) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 0) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 1) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 1) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 2) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 2) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 3) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 3) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 4) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 4) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 5) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 5) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 6) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 6) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 7) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 7) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 8) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 8) & 
(data['living_area'].isnull() == False), 'total_area']).median())

print ((data.loc[(data['rooms'] == 9) &
(data['living_area'].isnull() == False), 'living_area']/data.loc[(data['rooms'] == 9) & 
(data['living_area'].isnull() == False), 'total_area']).median())
# Out:
# 0.6896551724137931
# 0.48245614035087714
# 0.5851063829787234
# 0.6316666666666666
# 0.6594614550057261
# 0.6518423782149324
# 0.6794117647058824
# 0.6816702819956616
# 0.6884754302364403
# 0.6282513005202081

# %% [markdown]
# Заполним пропуски в living_area

# %%
data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 0), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 0), 'total_area'] * 0.69

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 1), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 1), 'total_area'] * 0.48

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 2), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 2), 'total_area'] * 0.585

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 3), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 3), 'total_area'] * 0.63

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 4), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 4), 'total_area'] * 0.66

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 5), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 5), 'total_area'] * 0.65

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 6), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 6), 'total_area'] * 0.68

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 7), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 7), 'total_area'] * 0.68

data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 9), 'living_area'] = data.loc[(data['living_area'].isnull() == True) & 
(data['rooms'] == 9), 'total_area'] * 0.63

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Отличная идея :) Все это можно сделать проще:</div>

# %% [raw]
# # КОД РЕВЬЮЕРА
#
# # Вспомогательная таблица для удобства и наглядности
# b = data.groupby('rooms').agg({'living_area': 'median', 'kitchen_area': 'median', 'total_area': 'median'})
#
# b['kitchen_coeff'] = (b['kitchen_area']/b['total_area']).round(2)
# b['living_coeff'] = (b['living_area']/b['total_area']).round(2)
# b

# %% [raw]
# # КОД РЕВЬЮЕРА
#
# # 3-к квартира, коэфф-т жилой к общей:
# b.loc[3][4]

# %% [raw]
# # КОД РЕВЬЮЕРА
#
# # 3-к квартира, коэфф-т кухни к общей:
# b.loc[3][3]

# %% [raw]
# # КОД РЕВЬЮЕРА
#
# # Можно даже в лямбде сделать
# def find_area(row, b, k):
#
#
#     '''Берет текущую площадь и находит нужный коэфф по таблице.
#     k определяет кухню и жилую.'''
#
#     return row['total_area'] * b.loc[row['rooms']][k]

# %% [raw]
# # КОД РЕВЬЮЕРА
#
# # Так сработает apply для жилых комнат.
# data.apply(lambda row: find_area(row, b, 4), 1)

# %% [raw]
# # КОД РЕВЬЮЕРА 1 (Не запускаю)
#
# # Вот так применяем к таблице.
#
#
# # Записываем результат работы функции в новый столбец.
# data['new_data'] = data.apply(lambda row: find_area(row, b, 4), 1)
#
# # Заполняем с пом. нового столбца пропуски. Пандас сам вытащит значения из этого столбца.
# data['living_area'] = data['living_area'].fillna(data['new_data'])

# %% [raw]
# # КОД РЕВЬЮЕРА 2 (Не запускаю)
#
# # А вот так мы столбец создадим, но сохранять не будем. Замену произведем в воздухе:
# data['living_area'] = data['living_area'].fillna(data.apply(lambda row: find_area(row, b, 4), axis=1))
#
# # Кухня:
# data['kitchen_area'] = data['kitchen_area'].fillna(data.apply(lambda row: find_area(row, b, 3), axis=1))

# %% [raw]
# # КОД РЕВЬЮЕРА 3 (Не запускаю)
#
# # Все то же самое, но функцию не используем уже, ведь достаточно лямбды.
#
# data['living_area'] = data['living_area'].fillna(data.apply(lambda row: (row['total_area'] * b.loc[row['rooms']][4]), 1))
# data['kitchen_area'] = data['kitchen_area'].fillna(data.apply(lambda row: (row['total_area'] * b.loc[row['rooms']][3]), 1))

# %% [raw]
# # КОД РЕВЬЮЕРА 4 (Не запускаю)
#
# # Еще вариант.
# data['living_area'] = data.groupby('rooms')['living_area'].apply(lambda a: a.fillna((data['living_area'].median()/data['total_area'].median())*data['total_area'].round()))

# %% [raw]
# # КОД РЕВЬЮЕРА 5 (Не запускаю)
#
# # Сложный вариант.
# data['liv_coef'] = data['living_area']/data['total_area']
#
# data['living_area'] = data['living_area'].fillna((data['rooms'].map(data.groupby('rooms')['liv_coef'].median().to_dict()))*data['total_area'])

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Мне больше нравится создавать вспомогательную таблицу. </div>

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# parks_nearest            15472
# ponds_nearest            14450
# airports_nearest          5420
# cityCenters_nearest       5397
# ponds_around3000          5396
# parks_around3000          5396
# days_exposition           3154
# kitchen_area              2241
# floors_total                84
# ceiling_height_median       14
# locality_name               14
# last_price                   0
# total_area                   0
# first_day_exposition         0
# rooms                        0
# ceiling_height               0
# open_plan                    0
# living_area                  0
# floor                        0
# is_apartment                 0
# studio                       0
# balcony                      0
# total_images                 0
# dtype: int64

# %% [markdown]
# **Заполним пропуски в locality_name (название населенного пункта)**

# %% [markdown]
# Т.к. процент пропуска от общего чилса населенног пункта равен 0,5 %, просто удалим их, это не повлияет на общий вывод

# %%
data.dropna(subset = ['locality_name'],inplace = True)
data['locality_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# К тому же, мы не можем быть уверены, что эти квартиры принадлежат Лен области. </div>

# %% [markdown]
# пропуски в названии населенного пункта заполнены

# %% [markdown]
# **Заполним пропуски в столбце kitchen_area (площадь кухни), таких пропусков 2240 шт или 1% от общего количеста, думаю данные пропуски могли возникнуть по причене того, что кухня совмещена с гостинной , попробуем заполнить пропуски разбив общую площадь на категории и посчитаем медиану, т.к. у нас площадь кухни коррелируется с общей площадью**

# %%
print(data['total_area'].describe())
print(data['kitchen_area'].corr(data['total_area']))
# Out:
# count    23529.000000
# mean        60.388915
# std         35.729817
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64
# 0.608785417306254

# %%
print((data.loc[(data['total_area'] <= 40), 
'kitchen_area']/data.loc[(data['total_area'] <= 40), 'total_area']).median())

print((data.loc[(data['total_area'] > 40) & 
(data['total_area'] <= 52), 'kitchen_area']/data.loc[(data['total_area'] > 40) & 
(data['total_area'] <= 52), 'total_area']).median())

print((data.loc[(data['total_area'] > 52) & 
(data['total_area'] <= 70), 'kitchen_area']/data.loc[(data['total_area'] <= 70) & 
(data['total_area'] > 52), 'total_area']).median())

print((data.loc[(data['total_area'] > 70) & 
(data['total_area'] <= 150), 'kitchen_area']/data.loc[(data['total_area'] > 70) & 
(data['total_area'] <= 150), 'total_area']).median())

print((data.loc[(data['total_area'] > 150), 
'kitchen_area']/data.loc[(data['total_area'] > 150), 'total_area']).median())
# Out:
# 0.23684210526315788
# 0.16519823788546256
# 0.15407863950236833
# 0.14012435392744738
# 0.10807563338301043

# %%
data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] <= 40), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] <= 40), 'total_area'] * 0.24

data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >40) & (data['total_area'] <= 52), 'kitchen_area'] =data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >40) & (data['total_area'] <= 52),'total_area'] * 0.165

data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >52) & (data['total_area'] <= 70), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >52) & (data['total_area'] <= 70),'total_area'] * 0.15

data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >70) & (data['total_area'] <= 150), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >70) & (data['total_area'] <= 150),'total_area'] * 0.14

data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] >150), 'kitchen_area'] = data.loc[(data['kitchen_area'].isnull() == True) & 
(data['total_area'] > 150), 'total_area'] * 0.11


data['kitchen_area'].isnull().sum()
# Out:
# 0

# %%
columns_name=['balcony','last_price','floors_total','days_exposition','ponds_nearest','ponds_around3000',
             'parks_nearest','cityCenters_nearest','airports_nearest']
def func_to_int(data,name):
    data[name] = data.loc[data[name].notna(),name].astype('Int32',errors='ignore')
    return data
for row in columns_name:
    data = func_to_int(data,row)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.63            11        18.60      1         False  ...
# 2            2.70             5        34.30      4         False  ...
# 3            2.70            14       100.17      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    balcony    locality_name  airports_nearest  cityCenters_nearest  \
# ...

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# parks_nearest            15465
# ponds_nearest            14446
# airports_nearest          5418
# cityCenters_nearest       5395
# ponds_around3000          5394
# parks_around3000          5394
# days_exposition           3154
# floors_total                84
# ceiling_height_median        0
# living_area                  0
# last_price                   0
# total_area                   0
# first_day_exposition         0
# rooms                        0
# ceiling_height               0
# open_plan                    0
# floor                        0
# is_apartment                 0
# studio                       0
# kitchen_area                 0
# balcony                      0
# locality_name                0
# total_images                 0
# dtype: int64

# %% [markdown]
# **ВЫВОД**
# Были заменены пропуски в высоте потолков, площади кухни и жилой комнаты, названии населенного пункта, наличие/отсутствия балкона. Пропуски количестве дней размещения объявления, не трогал, т.к. позмоно квартира еще не продана, что касается по пропускам пакри, прудыб расстояние до центара, расстояние до аэропорта не будем их трогать т.к. это исказит статистику и дальнейшие рассчеты с выводами.

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00  2019-03-07T00:00:00      3
# 1                 7     3350000       40.40  2018-12-04T00:00:00      1
# 2                10     5196000       56.00  2015-08-20T00:00:00      2
# 3                 0    64900000      159.00  2015-07-24T00:00:00      3
# 4                 2    10000000      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23693             9     4600000       62.40  2016-08-05T00:00:00      3
# 23694             9     9700000      133.81  2017-03-21T00:00:00      3
# 23695            14     3100000       59.00  2018-01-15T00:00:00      3
# 23697            13    11475000       76.75  2017-03-28T00:00:00      2
# 23698             4     1350000       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Отличная работа.</div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# **Посчитаем и добавим в таблицу :
# ~цену квадратного метра;
# ~день недели, месяц и год публикации объявления;
# ~этаж квартиры; варианты — первый, последний, другой;
# ~соотношение жилой и общей площади, а также отношение площади кухни к общей.**

# %% [markdown]
# Но для начала поменяем тип столбца first_day_exposition

# %%
data['first_day_exposition'] = data['first_day_exposition'].astype('datetime64')

# %%
data['price_per_meter'] = data['last_price'] / data['total_area']
data['day_of_week'] = pd.DatetimeIndex(data['first_day_exposition']).day
data['day_of_week_name'] = data['first_day_exposition'].dt.weekday_name
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year
data['living_to_total'] = data['living_area'] / data['total_area']
data['kitchen_to_total'] = data['kitchen_area'] / data['total_area']
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.63            11        18.60      1         False  ...
# 2            2.70             5        34.30      4         False  ...
# 3            2.70            14       100.17      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    ponds_nearest  days_exposition  ceiling_height_median  price_per_meter  \
# ...

# %% [markdown]
# Напишем функцию для категоризации этажности квартиры

# %%
def floor_cat(row):
    total_floors = row['floors_total']
    floor = row['floor']
    if floor == total_floors:
        return 'Последний'
    elif floor == 1:
        return 'Первый'
    else:
        return 'Другой'
data['floor_cat'] = data.apply(floor_cat,axis=1)
data['floor_cat'].unique()
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23693             9     4600000       62.40           2016-08-05      3
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Здесь же можно заодно проверить, нет ли таких ситуаций, что этаж рассматриваемой квартиры выше общего их числа в доме.
#
# </div>

# %% [markdown]
# **Вывод**
# Были добавлены новые столбцы с ценой квадратного метра, днем недели, месяцем, годом публикаци объявления и соотношением жилой площади и кухни к общей площади квартиры, а также была сделана категоризация этажей квартиры. Подготовили таблицу для проведения исследования.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **Что нужно сделать**
# Изучите следующие параметры: площадь, цена, число комнат, высота потолков.
# Постройте гистограммы для каждого параметра.
# Изучите время продажи квартиры. Постройте гистограмму.
# Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа.
# Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
# Какие факторы больше всего влияют на стоимость квартиры?
# Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.
# Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
# Также изучите зависимость от даты размещения: дня недели, месяца и года.
# Выберите 10 населённых пунктов с наибольшим числом объявлений.
# Посчитайте среднюю цену квадратного метра в этих населённых пунктах.
# Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья.
# Эти данные можно найти по имени в столбце 'locality_name'.
# Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра.
# Выделите квартиры в Санкт-Петербурге ('locality_name').
# Ваша задача — выяснить, какая область входит в центр.
# Создайте столбец с расстоянием до центра в километрах: округлите до целых значений.
# После этого посчитайте среднюю цену для каждого километра.
# Постройте график: он должен показывать, как цена зависит от удалённости от центра.
# Определите границу, где график сильно меняется — это и будет центральная зона.
# Выделите сегмент квартир в центре.
# Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.
# Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).
# Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# **Изучим некоторые параметры таблицы(площадь, цена, число комнатб высота потолков) и построим для них гистограммы.**

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height','price_per_meter']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height  \
# count  23529.000000  2.352900e+04  23529.000000    23529.000000
# mean      60.388915  6.565835e+06      2.070976        2.733949
# std       35.729817  1.091872e+07      1.079811        1.012964
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.450000e+06      1.000000        2.550000
# 50%       52.000000  4.650000e+06      2.000000        2.700000
# 75%       70.000000  6.800000e+06      3.000000        2.700000
# max      900.000000  7.630000e+08     19.000000      100.000000
#
#        price_per_meter
# count     2.352900e+04
# mean      9.975560e+04
# std       5.024827e+04
# min       1.118349e+02
# 25%       7.692308e+04
# 50%       9.516129e+04
# 75%       1.143624e+05
# max       1.907500e+06

# %% [raw]
# ~по площади есть как квартира 12 кв.м., так и 900 кв.м.
# ~по цене за квартиру - есть варианты и за 12 тысяч рублей, есть за 763 млн;
# ~число комнат - от 0 (студия) до 19.
# ~высота потолков - от 1 до 100 метров.
# Итог: среднии сзначения везде выглядят правдоподобноб, min и max похоже на выбросы данных.

# %%
data_names=['total_area','last_price','rooms','ceiling_height', 'price_per_meter']
data_bins=[100,100,8,15,30]
data_ranges=[(23,300),(0,30*10**6),(0,8),(2.5,4), (1, 1000000)]
data_xlabel=['Площадь','Цена','Комнаты','Высота потолков', 'Цена за метр']
i=0
for row in data_names:
    print(i+1,')',data_xlabel[i])
    total_area_data=data[row].hist(bins=data_bins[i],range=data_ranges[i]);
    plt.xlabel(data_xlabel[i],fontsize='x-large')
    plt.ylabel("Частота",fontsize='x-large')
    plt.title("Исследование основных параметров",fontsize='xx-large')
    plt.show()
    i+=1
# Out:
# 1 ) Площадь
# 2 ) Цена
# 3 ) Комнаты
# 4 ) Высота потолков
# 5 ) Цена за метр

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Здорово, что добавляешь подписи на графики.
# </div>

# %% [markdown]
# **Вывод: Гистограмма стоимости квадратного метра похожа на нормалное распределение с пиком на 100 000 за квадратный метр. Гистограмма стоимости квартиры скошена и имеет пик в районе 3 000 000 . При этом имеются и подозрительно маленькие и боьшие значения стоимости
# Наиболеечастые размеры квартир около 50 кв. метров. После 125 кв. метров имеется хвост. Но имеются и квартиры меньше 20 кв. метров(комната в комуналке :) или общежитии).
# Высота потолков имеет пик в районе 2.7 метров. Наиболее часто встречающаяся высота потолков 2.5-3 метра.
# Чаще всего встречаются однокомнатные квартиры, реже 2-ух, 3-х и 4-х комнатные.**

# %% [markdown]
# **Изученим временя продажи квартиры**

# %%
data['days_exposition'].describe()
# Out:
# count    20375.000000
# mean       180.980270
# std        220.036954
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Видно, что среднее значение в практически в два раза меньши медианы. Это может быть из-за не закрытых объявлений. Построим гистограмму и диаграмму размаха

# %%
data['days_exposition'].hist(bins=200, range =(1, 100))
plt.show()
data.boxplot(column='days_exposition')
plt.ylim(0,1000)
# Out:
# (0, 1000)

# %% [markdown]
# По статистике РБК среднее время продажи квартиры от 57 до до 92 дней (данные за 2020 год), т.е. квартиры проданные  в течении 30-45 дней можно считать проданными быстро, если квартира продана за год, можно сказать, что её продавали долго.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Согласна.
# </div>

# %% [markdown]
# **Создадим новую таблицу без выбросов**

# %%
data_new=data.query('days_exposition<365 and ceiling_height>2.4 and ceiling_height<4 and rooms<10 and last_price<50000000 and last_price>500000 and total_area<500 and total_area>17')
data_new
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1                 7     3350000       40.40           2018-12-04      1
# 4                 2    10000000      100.00           2018-06-19      2
# 5                10     2890000       30.40           2018-09-10      1
# 6                 6     3700000       37.30           2017-11-02      1
# 8                20     2900000       33.16           2018-05-23      1
# ...             ...         ...         ...                  ...    ...
# 23688            19     9200000      101.00           2019-04-01      3
# 23689            13     3550000       35.30           2018-02-28      1
# 23690             3     5500000       52.00           2018-07-19      2
# 23693             9     4600000       62.40           2016-08-05      3
# 23695            14     3100000       59.00           2018-01-15      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# В итоге цену и площадь сверху не будем ограничивать?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Да, спасибо, ограничил, квартиры квартиры более 500 кв. м. выглядят не провдаподобно и цена 763 млн тоже</h2>

# %% [markdown]
# Построим графики зависимости цены от площади квартиры, количества комнат, удаленности от центра и рассчитаем коэф. корреляции.

# %%
data_new_names=['total_area','rooms','cityCenters_nearest']
data_new_titles=['Цена от площади','Цена от комнат','Цена от расстояния до центра']
data_new_xlabel=["Площадь","Комнаты","Расстояние до центра"]
data_new_end=[]
i=0
for row in data_new_names:   
    k=data_new.plot(x = row, y = 'last_price',style='o',grid=True)
    if row=='rooms':
        plt.xlim(0,10)
    plt.xlabel(data_new_xlabel[i],fontsize='x-large')
    plt.ylabel('Цена',fontsize='x-large')
    plt.title(data_new_titles[i],fontsize='xx-large')
    data_new_end.append(k)
    plt.show()
    i+=1

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Легенды можно убрать.
# </div>

# %%
data_new_corr=data_new.loc[:,['last_price','total_area','rooms','cityCenters_nearest']]
data_new_corr.corr()
# Out:
#                      last_price  total_area     rooms  cityCenters_nearest
# last_price             1.000000    0.772630  0.495310            -0.317674
# total_area             0.772630    1.000000  0.768944            -0.200485
# rooms                  0.495310    0.768944  1.000000            -0.151395
# cityCenters_nearest   -0.317674   -0.200485 -0.151395             1.000000

# %% [markdown]
# Видим, что цена  зависит от площади квартиры(положительный коэф. корреляции), меньше зависит от числа комнат. От удаленности от центра зависит не так сильно, но при увеличении расстояния цена уменьшается(отрицательная корреляция)

# %% [markdown]
# Рассмотрим теперь зависимость от этажа. Рассчитаем медиану для каждого и построим график.

# %%
data_floor=data_new.pivot_table(index= 'floor_cat', values = 'last_price', aggfunc = 'median')
data_floor.plot(grid = False, kind='bar', figsize = (4,4));
plt.title('Цена от этажа',fontsize=10)
plt.xlabel('Этаж',fontsize=10)
plt.ylabel('Цена',fontsize=10)
plt.show()

# %% [markdown]
# Из графика видно, что квартира на первом этаже дешевле порядка 700 000 руб. чем на последнем и порядка 1 000 000 руб., чем на других.

# %% [markdown]
# **Выведим зависимость стомости  от дня месяца и года**

# %%
data_new_columns=['day_of_week_name','month','year']
data_new_date_analysis=[]
xlabels=['День недели','Месяц','Год']
i=0
for row in data_new_columns:
    data_new_cycle= data_new.pivot_table(index = row, values = 'last_price', aggfunc = 'median')
    k=data_new_cycle.plot(kind = 'bar', grid = True, figsize = (9,9));
    plt.xlabel(xlabels[i],fontsize='x-large')
    plt.ylabel('Медиана цены',fontsize='x-large')
    plt.title('Зависимость цены от времени',fontsize='xx-large')
    data_new_date_analysis.append(k)
    i+=1

# %% [raw]
# Вывод:
# 1) Цена не зависит от дня, когда вывешивается объявление о продаже.
# 2)  Цена не зависит от месяца, когда вывешивается объявление о продаже
# 3) Видим, что в последние два года наблюдается рост. Делаем вывод, что цена зависит от года(от экономической ситуации в стране, а точнее скорей всего из-за снижения ипотечной ставки, в 2015 продажи были выше уровня 2019 год., т.к. ожидалось повышении из-за политического коризиса и люди, которые обладали средствами вкладыли их в недвижимсть).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Верно.
# </div>

# %%
top10 = data['locality_name'].value_counts().index.tolist()[:10]
mean10_metrics = [data[data['locality_name'] == city]['price_per_meter'].median().round(2) for city in top10]
mean10_prices = [data[data['locality_name'] == city]['last_price'].median() for city in top10]
frame = {'Город': top10, 'Средняя цена за кв.м., тыс. руб.': mean10_metrics, 'Средняя цена за квартиру, тыс. руб.': mean10_prices}
dataframe = pd.DataFrame(frame).sort_values(by='Средняя цена за кв.м., тыс. руб.', ascending=False)
dataframe
# Out:
#                Город  Средняя цена за кв.м., тыс. руб.  \
# 0    Санкт-Петербург                         104761.90
# 4             Пушкин                         100000.00
# 8    деревня Кудрово                          91860.47
# 6  посёлок Парголово                          91642.86
# 1     посёлок Мурино                          85878.46
# 2     посёлок Шушары                          76876.17
# 5            Колпино                          74723.75
# 7            Гатчина                          67796.61
# 3         Всеволожск                          65789.47
# 9             Выборг                          58158.32
#
#    Средняя цена за квартиру, тыс. руб.
# 0                            5500000.0
# 4                            5180000.0
# 8                            3790000.0
# 6                            4100000.0
# 1                            3400000.0
# 2                            3950000.0
# 5                            3600000.0
# ...

# %%
dataframe.plot(kind='bar')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера</b>
#
# Цена за квадрат тут лишняя :)
# </div>

# %% [markdown]
# Cамые дорогие квартиры (что за всё жилье, что за 1 кв.м.) в Санкт-Петербурге и  городе Пушкине. Чем дальше от города, тем дешевле. В Выборге средняя цена за квадратный метр в 2 раз ниже, чем в Санкт-Петербурге.

# %% [markdown]
# **Создаем столбец с расстоянием до центра Санкт-Петербурга в километрах: округлим до целых значений.**

# %%
pd.options.mode.chained_assignment = None
data_new['cityCenters_nearest_round'] = (data_new['cityCenters_nearest'] / 1000).round(0)
data_new['cityCenters_nearest_round'] =  data_new['cityCenters_nearest_round']

# %%
price_per_km = data_new.query('locality_name=="Санкт-Петербург"').pivot_table(index = 'cityCenters_nearest_round',
                                                                            values = 'price_per_meter',aggfunc = 'mean')
price_per_km_graphic=price_per_km.plot(kind = 'bar',figsize = (14 , 9),grid=True,legend=True);
plt.title('Средняя цена за километр',fontsize='xx-large')
plt.xlabel('Расстояние до центра, км',fontsize='x-large')
plt.ylabel('Средняя цена',fontsize='x-large')
# Out:
# Text(0, 0.5, 'Средняя цена')

# %% [markdown]
# Резкое падение цен у трех км, дальше снова идет повышение(что-то странное находится на 3 км, но для центра как-то мало). Будем считать радиус центральной зоны 3 км. Выделим таблицу с объявлениями в центре. Также виден скачек на 27 км, возможно какой-то "элитный район" или застройка класса "А".

# %%
city_center_data = data_new.query('cityCenters_nearest_round <= 3')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Город не такой большой. 9 км захватит еще два района, помимо центра. Предлагаю 3 км. Подъем после 3 можно объяснить тем, что тут появляются квартиры с большей площадью. И это действительно так и есть. Если взять 5 км от центра на север, то попадем на очень и очень дорогую недвижимость с чуть ли не лучшим видом в городе. Хотя это не будет центральным районом. Я тебе предлагаю брать меньший радиус, руководствуясь здравым смыслом: диаметр 18 км это как-то слишком.  Как ты считаешь?
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Спасибо, учёл комментарий, на счет диаметра 18 км согласен, но я не нашел в свободных источниках, какой радиус в Питере считается центром, я руководствовался такой логикой, сам долгое время проживал в Краснодаре, центр краснодара это диаметр примерно 8-9 метров, ну и масштабировал на Питер)), плюс у Краснодара например условно два центра, "старый" и "новый". Но видимо, ты или живешь/жила в Санкт-Петербргу или много работала с недвижимостью, поверю профи...)  Максимум, что я нашел это районы относящеся к центру, а именно Адмиралтейского, Невского, Василеостровской также относят Петроградский, попробовал проверить по гугл картам, примерно вышло 7,2 км. ![image.png](attachment:image.png)
#   © https://peterburg.center/story/gde-centr-sankt-peterburga.html </h2>

# %%
city_center_data_bins=[100,8,100,15]
city_center_data_bins_titles=['Площадь','Комнаты','Цена','Высота потолков']
city_center_data_bins_ranges=[(0,300),(0,8),(0,5*10**7),(2.5,4)]
city_center_columns=['total_area','rooms','last_price','ceiling_height']
city_center_data_main=[]
i=0
for row in city_center_columns:
    l=city_center_data[row].plot(kind = 'hist',
                               bins = city_center_data_bins[i],
                               grid = True, range = city_center_data_bins_ranges[i])
    city_center_data_main.append(l)
    plt.title(city_center_data_bins_titles[i],fontsize='xx-large')
    plt.xlabel(city_center_data_bins_titles[i],fontsize='x-large')
    plt.ylabel('Частота',fontsize='x-large')
    plt.show()
    i+=1

# %% [raw]
# По графикам можно сделать следующие выводы:
# 1) Квартир прощадью до 50 м. кв намного меньше в центре, преобладает диапазон от 50 до 100 м.кв.
# 2) Квартиры дороже. Обычные стоят в среднем около 4 млн, а в центре около 6 млн.
# 3) В центре меньше однушек, преобладают двушки и трешки
# 4) Распределение высоты потолков одинаковое(но высотой 3м выделяются теперь заметнее).

# %%
city_center_columns=['day_of_week_name','month','year']
city_center_date_analysis=[]
xlabels=['День недели','Месяц','Год']
i=0
for row in city_center_columns:
    city_center_data_cycle= city_center_data.pivot_table(index = row, values = 'last_price', aggfunc = 'median')
    k=city_center_data_cycle.plot(kind = 'bar', grid = True, figsize = (9,9));
    #plt.ylim(0,10000000)
    plt.xlabel(xlabels[i],fontsize='x-large')
    plt.ylabel('Медиана цены',fontsize='x-large')
    plt.title('Зависимость цены от времени',fontsize='xx-large')
    city_center_date_analysis.append(k)
    i+=1

# %% [markdown]
# Различия в днях и месяцах не замечается(кроме декабря и ноября, но это не играет большой роли). Разница в годах координально отличается. Цена на недвижимость с годами падает, а 2016 год был самый выгодный.

# %%
city_center_data_corr = city_center_data.loc[:,['last_price','total_area','rooms','cityCenters_nearest','ceiling_height']]
city_center_data_corr.corr()
# Out:
#                      last_price  total_area     rooms  cityCenters_nearest  \
# last_price             1.000000    0.707116  0.485611            -0.160517
# total_area             0.707116    1.000000  0.805222            -0.093100
# rooms                  0.485611    0.805222  1.000000            -0.073349
# cityCenters_nearest   -0.160517   -0.093100 -0.073349             1.000000
# ceiling_height         0.061990    0.101669  0.029192            -0.037095
#
#                      ceiling_height
# last_price                 0.061990
# total_area                 0.101669
# rooms                      0.029192
# cityCenters_nearest       -0.037095
# ceiling_height             1.000000

# %% [markdown]
# Параметры ценообразования остаются те же.

# %%
city_center_data.describe()
# Out:
#        total_images    last_price  total_area       rooms  ceiling_height  \
# count    503.000000  5.030000e+02  503.000000  503.000000      503.000000
# mean      10.202783  1.087568e+07   87.314950    2.910537        2.995646
# std        6.254770  7.049136e+06   42.235157    1.329241        0.329279
# min        0.000000  2.385000e+06   17.600000    0.000000        2.500000
# 25%        5.500000  6.600000e+06   59.900000    2.000000        2.700000
# 50%       10.000000  8.900000e+06   79.000000    3.000000        2.900000
# 75%       15.000000  1.266500e+07  102.500000    4.000000        3.250000
# max       32.000000  4.990000e+07  315.000000    8.000000        3.900000
#
#        floors_total  living_area       floor  kitchen_area     balcony  ...  \
# count    502.000000   503.000000  503.000000    503.000000  503.000000  ...
# mean       4.846614    53.783201    2.978131     13.590753    0.091451  ...
# ...

# %%
#dataframe.describe()

# %%
data.corr()[['last_price']].sort_values(by='last_price', ascending=False)
# Out:
#                        last_price
# last_price               1.000000
# price_per_meter          0.737194
# total_area               0.653694
# living_area              0.586284
# kitchen_area             0.491127
# rooms                    0.363683
# ponds_around3000         0.160260
# parks_around3000         0.150825
# total_images             0.104256
# days_exposition          0.080631
# ceiling_height           0.064897
# is_apartment             0.026874
# floor                    0.025317
# ceiling_height_median    0.023387
# living_to_total          0.017417
# day_of_week              0.009356
# balcony                  0.008163
# month                    0.002745
# open_plan               -0.008657
# floors_total            -0.009034
# parks_nearest           -0.016310
# studio                  -0.025417
# airports_nearest        -0.026313
# year                    -0.042723
# ponds_nearest           -0.085205
# kitchen_to_total        -0.097675
# ...

# %% [markdown]
# Cамые дорогие квартиры (что за всё жилье, что за 1 кв.м.) в Санкт-Петербурге и  городе Пушкине. Чем дальше от города, тем дешевле. В Выборге средняя цена за квадратный метр в 2 раз ниже, чем в Санкт-Петербурге.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Были заполнены пропуски в данных: высота потолков (по среднему значению), жилая площадь (в зависимости от количества комнат), площадь кухни (по среднему отношению к площади квартиры). Был заменен тип object у количества дней размещений, названия населенного пункта и апартаментах для удобства дальнейшей работы
#
# В датасет были добавлены новые столбцы с ценой квадратного метра, категоризацией этажа квартиры, днем недели, месяцем, годом публикаци объявления и соотношением жилой площади и кухни к общей площади квартиры.
#
# Выяснили, что зависимость цены  от основных параметров и выяснили, что цена больше зависит от общей площади, чем от удаленности от центра
#
# Выяснили, что цена не зависит ото дня, в который она была выложена, так же как и от месяца. Есть цены  зависть от года, и в последние два года она начинает рости.
#
# Наиболее часто встречаются 1 и 2-х комнатные квартиры. Наиболее частые размеры 35-45 кв. метров.. Наиболее часто встречающаяся высота потолков 2.4-3 метра. Больше всего квартир было продано через 45 дней после выставления объявления
#
# Среди городов с наибольшим числом объявлений , самые дорогие цены за квадратный метр квартиры в Санкт-Петербурге, Пушкине и Сестрорецке, а вамые низкие цены в Красном Селе, Ломоносове и Кронштаде.
#
# Средняя стоимость квартиры в центре Питера  выше, чем средняя по городу ориентировчно, по городу 5-5,5 млн руб., то в центре доходит до 10 млн руб, а средняя 6 млн. руб  . Отличвается цена одного квадратого метро, в центре на 25 000 руб. выше . В центре в среднем 3-х комнатные квартиры против 2-х комнатных в среднем по городу. Соответсвенно и площадь квартир больше на 15 -20 кв.м. Соотношение квартир на разных этажах примерно одинаковое. Соотношния объявлений по дням недели, месяцам и годам примерно одинаковое, тенденции похожи.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера</b>
#
# Вывод хороший. В идеале стоит добавить медианы основных характеристик квартир для центра и для всей выборки, чтобы заказчику было понятно не только то, что квартиры в центре больше и дороже, но и насколько они больше и насколько дороже.
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [X]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [X]  изменены типы данных
# - [X]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
